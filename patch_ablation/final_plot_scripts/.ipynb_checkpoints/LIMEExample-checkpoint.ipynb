# %%
import os
import pickle as pkl
import scipy.spatial.distance as scipy_dist
import sys
sys.path.append('..')
sys.path.append('../../src')
import ds_utils

# %%
rootdir="/mnt/nfs/home/saachij/src/CausalDomainTransfer/patch_ablation/missingness_results/superpixel_redo/superpixel_patches_16_0_0_0"

# %%
model_name = 'resnet50'
lime_file = os.path.join(rootdir, model_name, "lime.pkl")
with open(lime_file, 'rb') as f:
    resnet_50_lime = pkl.load(f)

# %%
model_name = 'deit_small_resnet_aug_missingness'
lime_file = os.path.join(rootdir, model_name, "lime.pkl")
with open(lime_file, 'rb') as f:
    deit_lime = pkl.load(f)

# %%
import torch
indexing = torch.nn.Upsample(scale_factor=16)(torch.arange(196).reshape((14, 14)).unsqueeze(0).unsqueeze(0).float()).squeeze()

# %%
def perform_mask(img, mask_order):
    for i in mask_order:
        img[..., indexing == i] = 0
    return img

# %%
dataset = ds_utils.ImageNetMegaDS()
# Out:
# length of DS 10000

# %%
def get_softmaxed(a):
    a = torch.tensor(a).unsqueeze(0)
    return torch.softmax(a, dim=1).numpy()

# %%
import torchvision
import matplotlib.pyplot as plt
for b in [100, 606]:
    print(b)
    meta = dataset[b]
    for l in [deit_lime, resnet_50_lime]:
        print("----")
        plt.imshow(torchvision.transforms.ToPILImage()(meta['image']))
        plt.axis(False)
        plt.show()
        plt.imshow(l['lime_coeffs'][b].reshape(14, 14))
        plt.axis(False)
        plt.show()
        masked_image = perform_mask(meta['image'].clone(), l['lime_ordering'][b][:20])
        plt.imshow(torchvision.transforms.ToPILImage()(masked_image))
        plt.show()
# Out:
# 100
# ----
# ----
# 606
# ----
# ----

# %%
get_softmaxed(resnet_50_lime['lime_coeffs'][b])
# Out:
# array([[0.00510206, 0.00510204, 0.00510203, 0.00510206, 0.00510203,
#         0.00510204, 0.00510203, 0.00510205, 0.00510206, 0.00510206,
#         0.00510205, 0.00510206, 0.00510205, 0.00510207, 0.00510204,
#         0.00510209, 0.00510206, 0.00510208, 0.00510207, 0.00510205,
#         0.00510203, 0.00510207, 0.00510205, 0.00510204, 0.00510204,
#         0.00510205, 0.00510204, 0.00510202, 0.00510202, 0.00510204,
#         0.00510203, 0.00510203, 0.00510205, 0.00510207, 0.00510203,
#         0.00510204, 0.00510201, 0.00510204, 0.00510205, 0.00510204,
#         0.00510206, 0.00510203, 0.00510205, 0.00510205, 0.00510204,
#         0.00510202, 0.00510203, 0.00510204, 0.00510204, 0.00510204,
#         0.00510201, 0.00510204, 0.00510204, 0.00510208, 0.00510203,
#         0.00510203, 0.00510203, 0.00510202, 0.00510206, 0.00510205,
#         0.00510202, 0.00510202, 0.00510202, 0.00510205, 0.00510207,
#         0.00510202, 0.00510203, 0.00510205, 0.00510206, 0.00510204,
#         0.00510206, 0.00510204, 0.00510202, 0.00510201, 0.00510203,
#         0.00510203, 0.00510203, 0.00510203, 0.00510204, 0.00510204,
#         0.00510207, 0.00510203, 0.00510204, 0.00510204, 0.00510204,
#         0.00510205, 0.00510201, 0.00510204, 0.00510205, 0.00510204,
#         0.00510205, 0.00510201, 0.00510206, 0.00510203, 0.00510202,
#         0.00510203, 0.00510204, 0.00510206, 0.00510204, 0.00510203,
#         0.00510204, 0.00510203, 0.00510204, 0.00510206, 0.00510205,
#         0.00510206, 0.00510206, 0.00510204, 0.00510205, 0.00510204,
#         0.00510203, 0.00510202, 0.00510202, 0.00510203, 0.00510202,
#         0.00510204, 0.00510205, 0.00510206, 0.00510202, 0.00510204,
#         0.00510206, 0.00510204, 0.00510203, 0.00510207, 0.00510205,
#         0.00510205, 0.005102  , 0.00510204, 0.00510203, 0.00510204,
#         0.00510203, 0.00510205, 0.00510202, 0.00510204, 0.00510204,
#         0.00510205, 0.00510203, 0.005102  , 0.00510203, 0.00510205,
#         0.00510202, 0.00510203, 0.00510207, 0.00510202, 0.00510206,
#         0.00510206, 0.00510204, 0.00510206, 0.00510206, 0.00510202,
#         0.00510207, 0.00510204, 0.005102  , 0.00510206, 0.00510204,
#         0.00510203, 0.00510207, 0.00510204, 0.00510203, 0.00510205,
#         0.00510204, 0.00510202, 0.00510203, 0.00510205, 0.00510204,
#         0.00510203, 0.00510206, 0.00510205, 0.00510205, 0.00510206,
#         0.00510204, 0.00510204, 0.00510207, 0.00510203, 0.00510202,
#         0.00510204, 0.00510204, 0.00510205, 0.00510203, 0.00510205,
#         0.00510203, 0.00510205, 0.00510203, 0.00510202, 0.00510203,
#         0.00510201, 0.00510204, 0.00510202, 0.00510203, 0.00510201,
#         0.00510203, 0.00510204, 0.00510205, 0.00510205, 0.00510205,
#         0.00510204]])

# %%
results = {}
for c in colors:
    p = os.path.join(rootdir, c)
    for m in os.listdir(p):
        if m not in results: 
            results[m] = []
        full_path = os.path.join(p, m, "lime.pkl")
        if os.path.exists(full_path):
            with open(full_path, 'rb') as f:
                results[m].append(pkl.load(f)['lime_ordering'])

# %%
import numpy as np
R = np.stack(results['deit_small_resnet_aug'])

# %%
all_random = []
for _ in range(8):
    random = []
    for _ in range(10000):
        arr = np.arange(196)
        np.random.shuffle(arr)
        random.append(arr)
    all_random.append(np.stack(random))
all_random = np.stack(all_random)

# %%
all_random.shape
# Out:
# (8, 10000, 196)

# %%
from functools import reduce

# %%
# def get_jaccards(R):
#     mega_all_ious = []
#     for b in range(10000):
#         if b % 1000 == 0:
#             print(b)
#         all_ious = []
#         for T in range(1, 196):
#             mask = np.zeros((8, 196))
#             np.put_along_axis(mask, R[:, b, :T], 1, axis=1)
#             all_ious.append(1-scipy_dist.pdist(mask, metric='jaccard'))
#         mega_all_ious.append(np.stack(all_ious))
#     mega_all_ious = np.stack(mega_all_ious)
#     jaccards = mega_all_ious
#     return jaccards
# resnet_jaccards_new = resnet_jaccards
# resnet_jaccards_new = resnet_jaccards_new.transpose(1, 0, 2)
# resnet_jaccards_new = resnet_jaccards_new.mean(1)
# resnet_jaccards_new = resnet_jaccards_new.reshape(resnet_jaccards_new.shape[0], -1)
# resnet_jaccards_new = resnet_jaccards_new[:, :10]
# import pandas as pd
# df = pd.DataFrame(resnet_jaccards_new)
# df['x'] = np.arange(1, 196)
# df = df.melt('x')

# %%
def get_jaccards(R):
    mega_all_ious = []
    for b in range(10000):
        if b % 1000 == 0:
            print(b)
        all_ious = []
        for T in range(1, 196):
            mask = np.zeros((8, 196))
            np.put_along_axis(mask, R[:, b, :T], 1, axis=1)
            all_ious.append(1-scipy_dist.pdist(mask, metric='jaccard').mean())
        mega_all_ious.append(all_ious)
    mega_all_ious = np.stack(mega_all_ious)
    jaccards = mega_all_ious.mean(axis=0)
    return jaccards

# %%
resnet_jaccards = get_jaccards(np.stack(results['resnet50']))
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000

# %%
transformer_jaccards = get_jaccards(np.stack(results['deit_small_resnet_aug']))
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000

# %%
random_jaccards = get_jaccards(all_random)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
sns.set(style='ticks', font='sans-serif', font_scale=1.5)
plt.style.use('ggplot')

# %%
vit_style = ['ViT-S (masking features)', 'green']
vit_miss_style = ['ViT-S (dropping tokens)', 'blue']
resnet_style = ['ResNet-50', 'red']
random_style = ['Random', 'gray']

# %%
def get_handles():
    fig, ax = plt.subplots(1, 1)
    dummy_x = np.arange(5)
    dummy_y = np.ones(5)
    for model_name, color in [resnet_style, vit_style, random_style, vit_miss_style]:
        sns.lineplot(x=dummy_x, y=dummy_y, color=color, linestyle='-', label=model_name, ax=ax)
    handles, labels = ax.get_legend_handles_labels()
    plt.show()
    return handles, labels
handles, labels = get_handles()
# print(handles[0].__dict__)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(6,5))
sns.lineplot(x=np.arange(1, 196), y=np.ones(195), linewidth=2, label=vit_miss_style[0], color=vit_miss_style[1], ax=ax)
sns.lineplot(x=np.arange(1, 196), y=transformer_jaccards, linewidth=2, label=vit_style[0], color=vit_style[1], ax=ax)
sns.lineplot(x=np.arange(1, 196), y=resnet_jaccards, linewidth=2, label=resnet_style[0], color=resnet_style[1], ax=ax)
sns.lineplot(x=np.arange(1, 196), y=random_jaccards, linewidth=2, label=random_style[0], color=random_style[1], ax=ax)
sns.lineplot(x=np.arange(1, 196), y=random_jaccards, linewidth=2, label=random_style[0], color=random_style[1], ax=ax)
plt.xlabel('Top K Features', fontsize=15)
plt.ylabel('Jaccard Similarity of \n Top K Feature Sets', fontsize=15)
plt.legend(handles,labels, frameon=True, bbox_to_anchor=(1.05, 0.5), loc='center left')
plt.savefig("consistency.pdf", bbox_inches='tight')
plt.show()

# %%
import scipy.spatial.distance.pdist as pdist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-102-6dfbc728e508> in <module>
# ----> 1 import scipy.spatial.distance.pdist as pdist
#
# ModuleNotFoundError: No module named 'scipy.spatial.distance.pdist'; 'scipy.spatial.distance' is not a package

# %%
import scipy.spatial.distance.pdist as pdist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-106-6dfbc728e508> in <module>
# ----> 1 import scipy.spatial.distance.pdist as pdist
#
# ModuleNotFoundError: No module named 'scipy.spatial.distance.pdist'; 'scipy.spatial.distance' is not a package

# %%
dst.pdist([[0, 0, 1], [0, 0, 1]], metric='jaccard')
# Out:
# array([1.])
